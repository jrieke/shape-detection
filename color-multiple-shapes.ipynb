# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
import cairo
num_imgs = 50000

img_size = 32
min_object_size = 4
max_object_size = 16
num_objects = 2

bboxes = np.zeros((num_imgs, num_objects, 4))
imgs = np.zeros((num_imgs, img_size, img_size, 4), dtype=np.uint8)  # format: BGRA
shapes = np.zeros((num_imgs, num_objects), dtype=int)
num_shapes = 3
shape_labels = ['rectangle', 'circle', 'triangle']
colors = np.zeros((num_imgs, num_objects), dtype=int)
num_colors = 3
color_labels = ['r', 'g', 'b']

for i_img in range(num_imgs):
    surface = cairo.ImageSurface.create_for_data(imgs[i_img], cairo.FORMAT_ARGB32, img_size, img_size)
    cr = cairo.Context(surface)

    # Fill background white.
    cr.set_source_rgb(1, 1, 1)
    cr.paint()
    
    # TODO: Try no overlap here.
    # Draw random shapes.
    for i_object in range(num_objects):
        shape = np.random.randint(num_shapes)
        shapes[i_img, i_object] = shape
        if shape == 0:  # rectangle
            w, h = np.random.randint(min_object_size, max_object_size, size=2)
            x = np.random.randint(0, img_size - w)
            y = np.random.randint(0, img_size - h)
            bboxes[i_img, i_object] = [x, y, w, h]
            cr.rectangle(x, y, w, h)            
        elif shape == 1:  # circle   
            r = 0.5 * np.random.randint(min_object_size, max_object_size)
            x = np.random.randint(r, img_size - r)
            y = np.random.randint(r, img_size - r)
            bboxes[i_img, i_object] = [x - r, y - r, 2 * r, 2 * r]
            cr.arc(x, y, r, 0, 2*np.pi)
        elif shape == 2:  # triangle
            w, h = np.random.randint(min_object_size, max_object_size, size=2)
            x = np.random.randint(0, img_size - w)
            y = np.random.randint(0, img_size - h)
            bboxes[i_img, i_object] = [x, y, w, h]
            cr.move_to(x, y)
            cr.line_to(x+w, y)
            cr.line_to(x+w, y+h)
            cr.line_to(x, y)
            cr.close_path()
        
        # TODO: Introduce some variation to the colors by adding a small random offset to the rgb values.
        color = np.random.randint(num_colors)
        colors[i_img, i_object] = color
        max_offset = 0.3
        r_offset, g_offset, b_offset = max_offset * 2. * (np.random.rand(3) - 0.5)
        if color == 0:
            cr.set_source_rgb(1-max_offset+r_offset, 0+g_offset, 0+b_offset)
        elif color == 1:
            cr.set_source_rgb(0+r_offset, 1-max_offset+g_offset, 0+b_offset)
        elif color == 2:
            cr.set_source_rgb(0+r_offset, 0-max_offset+g_offset, 1+b_offset)
        cr.fill()
        
imgs = imgs[..., 2::-1]  # is BGRA, convert to RGB

# surface.write_to_png('imgs/{}.png'.format(i_img))
imgs.shape, bboxes.shape, shapes.shape, colors.shape
# Out:
# ((50000L, 32L, 32L, 3L), (50000L, 2L, 4L), (50000L, 2L), (50000L, 2L))

# %%
i = 5
plt.imshow(imgs[i], interpolation='none', origin='lower', extent=[0, img_size, 0, img_size])
for bbox, shape, color in zip(bboxes[i], shapes[i], colors[i]):
    plt.gca().add_patch(matplotlib.patches.Rectangle((bbox[0], bbox[1]), bbox[2], bbox[3], ec='k', fc='none'))
    plt.annotate(shape_labels[shape], (bbox[0], bbox[1] + bbox[3] + 0.7), color=color_labels[color], clip_on=False)
# surface.write_to_png("circle.png")

# %%
X = (imgs - 128.) / 255.
X.shape, np.mean(X), np.std(X)
# Out:
# ((50000L, 32L, 32L, 3L), 0.40545137653186303, 0.26626301805254604)

# %%
colors_onehot = np.zeros((num_imgs, num_objects, num_colors))
for i_img in range(num_imgs):
    for i_object in range(num_objects):
        colors_onehot[i_img, i_object, colors[i_img, i_object]] = 1

shapes_onehot = np.zeros((num_imgs, num_objects, num_shapes))
for i_img in range(num_imgs):
    for i_object in range(num_objects):
        shapes_onehot[i_img, i_object, shapes[i_img, i_object]] = 1
        
y = np.concatenate([bboxes / img_size, shapes_onehot, colors_onehot], axis=-1).reshape(num_imgs, -1)
y.shape, np.all(np.argmax(colors_onehot, axis=-1) == colors)
# Out:
# ((50000L, 20L), True)

# %%
i = int(0.8 * num_imgs)
train_X = X[:i]
test_X = X[i:]
train_y = y[:i]
test_y = y[i:]
test_imgs = imgs[i:]
test_bboxes = bboxes[i:]

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Convolution2D, MaxPooling2D, Flatten

# Activate GPU for this, otherwise the convnet will take forever to train with Theano.

# TODO: Make one run with very deep network (~10 layers).
filter_size = 3
pool_size = 2

# TODO: Maybe remove pooling bc it takes away the spatial information.

model = Sequential([
        Convolution2D(32, 6, 6, input_shape=X.shape[1:], dim_ordering='tf', activation='relu'), 
        MaxPooling2D(pool_size=(pool_size, pool_size)), 
        Convolution2D(64, filter_size, filter_size, dim_ordering='tf', activation='relu'), 
        MaxPooling2D(pool_size=(pool_size, pool_size)), 
        Convolution2D(128, filter_size, filter_size, dim_ordering='tf', activation='relu'), 
# #         MaxPooling2D(pool_size=(pool_size, pool_size)), 
        Convolution2D(128, filter_size, filter_size, dim_ordering='tf', activation='relu'), 
# #         MaxPooling2D(pool_size=(pool_size, pool_size)), 
        Flatten(), 
        Dropout(0.4), 
        Dense(256, activation='relu'), 
        Dropout(0.4), 
        Dense(y.shape[-1])
    ])

model.compile('adadelta', 'mse')

# %%
# Flip bboxes during training.
# Note: The validation loss is always quite big here because we don't flip the bounding boxes for the validation data. 
def IOU(bbox1, bbox2):
    '''Calculate overlap between two bounding boxes [x, y, w, h] as the area of intersection over the area of unity'''
    x1, y1, w1, h1 = bbox1[0], bbox1[1], bbox1[2], bbox1[3]  # TODO: Check if its more performant if tensor elements are accessed directly below.
    x2, y2, w2, h2 = bbox2[0], bbox2[1], bbox2[2], bbox2[3]

    w_I = min(x1 + w1, x2 + w2) - max(x1, x2)
    h_I = min(y1 + h1, y2 + h2) - max(y1, y2)
    if w_I <= 0 or h_I <= 0:  # no overlap
        return 0
    I = w_I * h_I

    U = w1 * h1 + w2 * h2 - I

    return I / U

def dist(bbox1, bbox2):
    return np.sqrt(np.sum(np.square(bbox1[:2] - bbox2[:2])))

num_epochs_flipping = 50
num_epochs_no_flipping = 0  # has no significant effect

flipped_train_y = np.array(train_y)
flipped = np.zeros((len(train_y), num_epochs_flipping + num_epochs_no_flipping))
ious_epoch = np.zeros((len(train_y), num_epochs_flipping + num_epochs_no_flipping))
dists_epoch = np.zeros((len(train_y), num_epochs_flipping + num_epochs_no_flipping))
mses_epoch = np.zeros((len(train_y), num_epochs_flipping + num_epochs_no_flipping))
acc_shapes_epoch = np.zeros((len(train_y), num_epochs_flipping + num_epochs_no_flipping))
acc_colors_epoch = np.zeros((len(train_y), num_epochs_flipping + num_epochs_no_flipping))

flipped_test_y = np.array(test_y)
flipped_test = np.zeros((len(test_y), num_epochs_flipping + num_epochs_no_flipping))
ious_test_epoch = np.zeros((len(test_y), num_epochs_flipping + num_epochs_no_flipping))
dists_test_epoch = np.zeros((len(test_y), num_epochs_flipping + num_epochs_no_flipping))
mses_test_epoch = np.zeros((len(test_y), num_epochs_flipping + num_epochs_no_flipping))
acc_shapes_test_epoch = np.zeros((len(test_y), num_epochs_flipping + num_epochs_no_flipping))
acc_colors_test_epoch = np.zeros((len(test_y), num_epochs_flipping + num_epochs_no_flipping))

# TODO: Calculate ious directly for all samples (using slices of the array pred_y for x, y, w, h).
for epoch in range(num_epochs_flipping):
    print 'Epoch', epoch
    model.fit(train_X, flipped_train_y, nb_epoch=1, validation_data=(test_X, test_y), verbose=2)
    pred_y = model.predict(train_X)

    for sample, (pred, exp) in enumerate(zip(pred_y, flipped_train_y)):
        
        # TODO: Make this simpler.
        pred = pred.reshape(num_objects, -1)
        exp = exp.reshape(num_objects, -1)
        
        pred_bboxes = pred[:, :4]
        exp_bboxes = exp[:, :4]
        
        ious = np.zeros((num_objects, num_objects))
        dists = np.zeros((num_objects, num_objects))
        mses = np.zeros((num_objects, num_objects))
        for i, exp_bbox in enumerate(exp_bboxes):
            for j, pred_bbox in enumerate(pred_bboxes):
                ious[i, j] = IOU(exp_bbox, pred_bbox)
                dists[i, j] = dist(exp_bbox, pred_bbox)
                mses[i, j] = np.mean(np.square(exp_bbox - pred_bbox))
                
        new_order = np.zeros(num_objects, dtype=int)
        
        for i in range(num_objects):
            # Find pred and exp bbox with maximum iou and assign them to each other (i.e. switch the positions of the exp bboxes in y).
            ind_exp_bbox, ind_pred_bbox = np.unravel_index(ious.argmax(), ious.shape)
            ious_epoch[sample, epoch] += ious[ind_exp_bbox, ind_pred_bbox]
            dists_epoch[sample, epoch] += dists[ind_exp_bbox, ind_pred_bbox]
            mses_epoch[sample, epoch] += mses[ind_exp_bbox, ind_pred_bbox]
            ious[ind_exp_bbox] = -1  # set iou of assigned bboxes to -1, so they don't get assigned again
            ious[:, ind_pred_bbox] = -1
            new_order[ind_pred_bbox] = ind_exp_bbox
        
        flipped_train_y[sample] = exp[new_order].flatten()
        
        flipped[sample, epoch] = 1. - np.mean(new_order == np.arange(num_objects, dtype=int))#np.array_equal(new_order, np.arange(num_objects, dtype=int))  # TODO: Change this to reflect the number of flips.
        ious_epoch[sample, epoch] /= num_objects
        dists_epoch[sample, epoch] /= num_objects
        mses_epoch[sample, epoch] /= num_objects
        
        acc_shapes_epoch[sample, epoch] = np.mean(np.argmax(pred[:, 4:4+num_shapes], axis=-1) == np.argmax(exp[:, 4:4+num_shapes], axis=-1))
        acc_colors_epoch[sample, epoch] = np.mean(np.argmax(pred[:, 4+num_shapes:4+num_shapes+num_colors], axis=-1) == np.argmax(exp[:, 4+num_shapes:4+num_shapes+num_colors], axis=-1))

    
    # Calculate metrics on test data. 
    pred_test_y = model.predict(test_X)
    # TODO: Make this simpler.
    for sample, (pred, exp) in enumerate(zip(pred_test_y, flipped_test_y)):
        
        # TODO: Make this simpler.
        pred = pred.reshape(num_objects, -1)
        exp = exp.reshape(num_objects, -1)
        
        pred_bboxes = pred[:, :4]
        exp_bboxes = exp[:, :4]
        
        ious = np.zeros((num_objects, num_objects))
        dists = np.zeros((num_objects, num_objects))
        mses = np.zeros((num_objects, num_objects))
        for i, exp_bbox in enumerate(exp_bboxes):
            for j, pred_bbox in enumerate(pred_bboxes):
                ious[i, j] = IOU(exp_bbox, pred_bbox)
                dists[i, j] = dist(exp_bbox, pred_bbox)
                mses[i, j] = np.mean(np.square(exp_bbox - pred_bbox))
                
        new_order = np.zeros(num_objects, dtype=int)
        
        for i in range(num_objects):
            # Find pred and exp bbox with maximum iou and assign them to each other (i.e. switch the positions of the exp bboxes in y).
            ind_exp_bbox, ind_pred_bbox = np.unravel_index(mses.argmin(), mses.shape)
            ious_test_epoch[sample, epoch] += ious[ind_exp_bbox, ind_pred_bbox]
            dists_test_epoch[sample, epoch] += dists[ind_exp_bbox, ind_pred_bbox]
            mses_test_epoch[sample, epoch] += mses[ind_exp_bbox, ind_pred_bbox]
            mses[ind_exp_bbox] = 1000000#-1  # set iou of assigned bboxes to -1, so they don't get assigned again
            mses[:, ind_pred_bbox] = 10000000#-1
            new_order[ind_pred_bbox] = ind_exp_bbox
        
        flipped_test_y[sample] = exp[new_order].flatten()
        
        flipped_test[sample, epoch] = 1. - np.mean(new_order == np.arange(num_objects, dtype=int))#np.array_equal(new_order, np.arange(num_objects, dtype=int))  # TODO: Change this to reflect the number of flips.
        ious_test_epoch[sample, epoch] /= num_objects
        dists_test_epoch[sample, epoch] /= num_objects
        mses_test_epoch[sample, epoch] /= num_objects
        
        acc_shapes_test_epoch[sample, epoch] = np.mean(np.argmax(pred[:, 4:4+num_shapes], axis=-1) == np.argmax(exp[:, 4:4+num_shapes], axis=-1))
        acc_colors_test_epoch[sample, epoch] = np.mean(np.argmax(pred[:, 4+num_shapes:4+num_shapes+num_colors], axis=-1) == np.argmax(exp[:, 4+num_shapes:4+num_shapes+num_colors], axis=-1))
       
            
    print 'Flipped {} % of all elements'.format(np.mean(flipped[:, epoch]) * 100.)
    print 'Mean IOU: {}'.format(np.mean(ious_epoch[:, epoch]))
    print 'Mean dist: {}'.format(np.mean(dists_epoch[:, epoch]))
    print 'Mean mse: {}'.format(np.mean(mses_epoch[:, epoch]))
    print 'Accuracy shapes: {}'.format(np.mean(acc_shapes_epoch[:, epoch]))
    print 'Accuracy colors: {}'.format(np.mean(acc_colors_epoch[:, epoch]))
    
    print '--------------- TEST ----------------'
    print 'Flipped {} % of all elements'.format(np.mean(flipped_test[:, epoch]) * 100.)
    print 'Mean IOU: {}'.format(np.mean(ious_test_epoch[:, epoch]))
    print 'Mean dist: {}'.format(np.mean(dists_test_epoch[:, epoch]))
    print 'Mean mse: {}'.format(np.mean(mses_test_epoch[:, epoch]))
    print 'Accuracy shapes: {}'.format(np.mean(acc_shapes_test_epoch[:, epoch]))
    print 'Accuracy colors: {}'.format(np.mean(acc_colors_test_epoch[:, epoch]))
    print
    
# print '------------------------------------'
# print 'Training now without flipping bboxes'
# print '------------------------------------'
    
# for epoch in range(num_epochs_flipping, num_epochs_flipping + num_epochs_no_flipping):
#     print 'Epoch', epoch
#     model.fit(train_X, flipped_train_y, nb_epoch=1, validation_data=(test_X, test_y), verbose=2)
#     pred_y = model.predict(train_X)

#     # Calculate iou/dist, but don't flip.
#     for sample, (pred_bboxes, exp_bboxes) in enumerate(zip(pred_y, flipped_train_y)):
        
#         pred_bboxes = pred_bboxes.reshape(num_objects, -1)
#         exp_bboxes = exp_bboxes.reshape(num_objects, -1)        
        
#         for exp_bbox, pred_bbox in zip(exp_bboxes, pred_bboxes):
#             ious_epoch[sample, epoch] += IOU(exp_bbox, pred_bbox)
#             dists_epoch[sample, epoch] += dist(exp_bbox, pred_bbox)
#             mses_epoch[sample, epoch] += np.mean(np.square(exp_bbox - pred_bbox))
            
#         ious_epoch[sample, epoch] /= num_objects
#         dists_epoch[sample, epoch] /= num_objects 
#         mses_epoch[sample, epoch] /= num_objects 
            
# #     print 'Flipped {} % of all elements'.format(np.mean(flipped[:, epoch]) * 100.)
#     print 'Mean IOU: {}'.format(np.mean(ious_epoch[:, epoch]))
#     print 'Mean dist: {}'.format(np.mean(dists_epoch[:, epoch]))
#     print 'Mean mse: {}'.format(np.mean(mses_epoch[:, epoch]))
#     print
# Out:
# Epoch 0
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.1347 - val_loss: 0.1122
# Flipped 46.7975 % of all elements
# Mean IOU: 0.21033079451
# Mean dist: 0.219388273656
# Mean mse: 0.0207690124663
# Accuracy shapes: 0.4178625
# Accuracy colors: 0.66785
# --------------- TEST ----------------
# Flipped 50.37 % of all elements
# Mean IOU: 0.206793675131
# Mean dist: 0.220010190271
# Mean mse: 0.0207248295481
# Accuracy shapes: 0.4137
# Accuracy colors: 0.66685
#
# Epoch 1
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.1068 - val_loss: 0.1047
# Flipped 24.2375 % of all elements
# Mean IOU: 0.243669244136
# Mean dist: 0.194529039042
# Mean mse: 0.0183214527394
# Accuracy shapes: 0.5530625
# Accuracy colors: 0.778025
# --------------- TEST ----------------
# Flipped 27.27 % of all elements
# Mean IOU: 0.238765597626
# Mean dist: 0.193855493724
# Mean mse: 0.0181368993602
# Accuracy shapes: 0.54235
# Accuracy colors: 0.7671
#
# Epoch 2
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0890 - val_loss: 0.1001
# Flipped 14.4875 % of all elements
# Mean IOU: 0.26844928384
# Mean dist: 0.178382605836
# Mean mse: 0.0162804254468
# Accuracy shapes: 0.7180625
# Accuracy colors: 0.852475
# --------------- TEST ----------------
# Flipped 15.71 % of all elements
# Mean IOU: 0.263017331421
# Mean dist: 0.176943816739
# Mean mse: 0.0160746197083
# Accuracy shapes: 0.71625
# Accuracy colors: 0.8476
#
# Epoch 3
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0743 - val_loss: 0.1036
# Flipped 11.9825 % of all elements
# Mean IOU: 0.289909705021
# Mean dist: 0.165374013296
# Mean mse: 0.0148229787364
# Accuracy shapes: 0.7886125
# Accuracy colors: 0.87825
# --------------- TEST ----------------
# Flipped 12.28 % of all elements
# Mean IOU: 0.284322291076
# Mean dist: 0.163859219319
# Mean mse: 0.0146139403248
# Accuracy shapes: 0.78275
# Accuracy colors: 0.8734
#
# Epoch 4
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0641 - val_loss: 0.1060
# Flipped 8.475 % of all elements
# Mean IOU: 0.308853796636
# Mean dist: 0.156508761661
# Mean mse: 0.0137840322475
# Accuracy shapes: 0.84555
# Accuracy colors: 0.9039375
# --------------- TEST ----------------
# Flipped 8.16 % of all elements
# Mean IOU: 0.303404962304
# Mean dist: 0.155804608785
# Mean mse: 0.0136887984626
# Accuracy shapes: 0.8363
# Accuracy colors: 0.8977
#
# Epoch 5
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0565 - val_loss: 0.1067
# Flipped 6.635 % of all elements
# Mean IOU: 0.314029170005
# Mean dist: 0.15214241441
# Mean mse: 0.0132217867671
# Accuracy shapes: 0.866675
# Accuracy colors: 0.910675
# --------------- TEST ----------------
# Flipped 6.9 % of all elements
# Mean IOU: 0.308088475416
# Mean dist: 0.152038971128
# Mean mse: 0.0131831493226
# Accuracy shapes: 0.86195
# Accuracy colors: 0.90335
#
# Epoch 6
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0522 - val_loss: 0.1116
# Flipped 6.9725 % of all elements
# Mean IOU: 0.323648503246
# Mean dist: 0.149720935395
# Mean mse: 0.0129679001781
# Accuracy shapes: 0.8841375
# Accuracy colors: 0.918475
# --------------- TEST ----------------
# Flipped 7.18 % of all elements
# Mean IOU: 0.317843105334
# Mean dist: 0.149850095575
# Mean mse: 0.0129751302853
# Accuracy shapes: 0.87605
# Accuracy colors: 0.9142
#
# Epoch 7
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0485 - val_loss: 0.1108
# Flipped 5.5575 % of all elements
# Mean IOU: 0.331833769185
# Mean dist: 0.143842773503
# Mean mse: 0.0122136618615
# Accuracy shapes: 0.9005125
# Accuracy colors: 0.927
# --------------- TEST ----------------
# Flipped 6.26 % of all elements
# Mean IOU: 0.325190797425
# Mean dist: 0.144330893657
# Mean mse: 0.0122614741864
# Accuracy shapes: 0.8907
# Accuracy colors: 0.9199
#
# Epoch 8
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0461 - val_loss: 0.1137
# Flipped 5.205 % of all elements
# Mean IOU: 0.341123800304
# Mean dist: 0.138611989252
# Mean mse: 0.0116363412781
# Accuracy shapes: 0.91
# Accuracy colors: 0.9310125
# --------------- TEST ----------------
# Flipped 5.91 % of all elements
# Mean IOU: 0.334229541869
# Mean dist: 0.13898259837
# Mean mse: 0.0116639406111
# Accuracy shapes: 0.89875
# Accuracy colors: 0.92455
#
# Epoch 9
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0438 - val_loss: 0.1154
# Flipped 5.4775 % of all elements
# Mean IOU: 0.347196235118
# Mean dist: 0.135402843612
# Mean mse: 0.011286528221
# Accuracy shapes: 0.9154375
# Accuracy colors: 0.9350375
# --------------- TEST ----------------
# Flipped 5.45 % of all elements
# Mean IOU: 0.340399955598
# Mean dist: 0.135880339479
# Mean mse: 0.0113277205003
# Accuracy shapes: 0.90535
# Accuracy colors: 0.9254
#
# Epoch 10
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0419 - val_loss: 0.1171
# Flipped 5.01 % of all elements
# Mean IOU: 0.352595007579
# Mean dist: 0.131331778453
# Mean mse: 0.010839763065
# Accuracy shapes: 0.9210875
# Accuracy colors: 0.9402625
# --------------- TEST ----------------
# Flipped 4.73 % of all elements
# Mean IOU: 0.344904714582
# Mean dist: 0.131795508729
# Mean mse: 0.0108526415574
# Accuracy shapes: 0.91375
# Accuracy colors: 0.93255
#
# Epoch 11
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0402 - val_loss: 0.1164
# Flipped 4.5025 % of all elements
# Mean IOU: 0.364728959218
# Mean dist: 0.12756954609
# Mean mse: 0.0105041218384
# Accuracy shapes: 0.92765
# Accuracy colors: 0.94225
# --------------- TEST ----------------
# Flipped 5.66 % of all elements
# Mean IOU: 0.357306740248
# Mean dist: 0.12848406333
# Mean mse: 0.0105880952593
# Accuracy shapes: 0.9183
# Accuracy colors: 0.93655
#
# Epoch 12
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0387 - val_loss: 0.1170
# Flipped 4.035 % of all elements
# Mean IOU: 0.364925211724
# Mean dist: 0.126165929141
# Mean mse: 0.0103198581811
# Accuracy shapes: 0.929975
# Accuracy colors: 0.946175
# --------------- TEST ----------------
# Flipped 4.81 % of all elements
# Mean IOU: 0.357064694339
# Mean dist: 0.12712101971
# Mean mse: 0.0104007427233
# Accuracy shapes: 0.91955
# Accuracy colors: 0.93915
#
# Epoch 13
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0376 - val_loss: 0.1187
# Flipped 3.7 % of all elements
# Mean IOU: 0.369254696014
# Mean dist: 0.123358855083
# Mean mse: 0.0100092818408
# Accuracy shapes: 0.9346875
# Accuracy colors: 0.947525
# --------------- TEST ----------------
# Flipped 4.26 % of all elements
# Mean IOU: 0.361223155484
# Mean dist: 0.124406362449
# Mean mse: 0.0100906098564
# Accuracy shapes: 0.9243
# Accuracy colors: 0.94105
#
# Epoch 14
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0365 - val_loss: 0.1205
# Flipped 3.525 % of all elements
# Mean IOU: 0.377190222808
# Mean dist: 0.119843913043
# Mean mse: 0.00971243673339
# Accuracy shapes: 0.938125
# Accuracy colors: 0.9498
# --------------- TEST ----------------
# Flipped 4.15 % of all elements
# Mean IOU: 0.369318178004
# Mean dist: 0.120866582707
# Mean mse: 0.00979346010223
# Accuracy shapes: 0.9261
# Accuracy colors: 0.9441
#
# Epoch 15
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0355 - val_loss: 0.1200
# Flipped 4.0725 % of all elements
# Mean IOU: 0.372567684376
# Mean dist: 0.122458577895
# Mean mse: 0.00986301875484
# Accuracy shapes: 0.937475
# Accuracy colors: 0.9499375
# --------------- TEST ----------------
# Flipped 4.58 % of all elements
# Mean IOU: 0.364496866812
# Mean dist: 0.123607131613
# Mean mse: 0.00997003841347
# Accuracy shapes: 0.92645
# Accuracy colors: 0.9408
#
# Epoch 16
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0352 - val_loss: 0.1186
# Flipped 3.8075 % of all elements
# Mean IOU: 0.378862576425
# Mean dist: 0.118363056562
# Mean mse: 0.00949066628347
# Accuracy shapes: 0.9395625
# Accuracy colors: 0.9502625
# --------------- TEST ----------------
# Flipped 4.28 % of all elements
# Mean IOU: 0.370230954942
# Mean dist: 0.119780553292
# Mean mse: 0.00960662508835
# Accuracy shapes: 0.92885
# Accuracy colors: 0.94035
#
# Epoch 17
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0344 - val_loss: 0.1211
# Flipped 3.72 % of all elements
# Mean IOU: 0.385145658264
# Mean dist: 0.116294739611
# Mean mse: 0.00928757912199
# Accuracy shapes: 0.9425625
# Accuracy colors: 0.9532375
# --------------- TEST ----------------
# Flipped 4.13 % of all elements
# Mean IOU: 0.3761576032
# Mean dist: 0.117867200291
# Mean mse: 0.00941588691813
# Accuracy shapes: 0.93015
# Accuracy colors: 0.94355
#
# Epoch 18
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 49s - loss: 0.0336 - val_loss: 0.1202
# Flipped 4.1025 % of all elements
# Mean IOU: 0.377865348683
# Mean dist: 0.11758913873
# Mean mse: 0.00937793612835
# Accuracy shapes: 0.9421875
# Accuracy colors: 0.9521875
# --------------- TEST ----------------
# Flipped 4.55 % of all elements
# Mean IOU: 0.368053820876
# Mean dist: 0.119188351002
# Mean mse: 0.00950210390399
# Accuracy shapes: 0.93065
# Accuracy colors: 0.94185
#
# Epoch 19
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0333 - val_loss: 0.1205
# Flipped 3.395 % of all elements
# Mean IOU: 0.39011896977
# Mean dist: 0.113913841529
# Mean mse: 0.00902453063088
# Accuracy shapes: 0.9446125
# Accuracy colors: 0.9531625
# --------------- TEST ----------------
# Flipped 4.2 % of all elements
# Mean IOU: 0.381516209716
# Mean dist: 0.115595224413
# Mean mse: 0.0091613603925
# Accuracy shapes: 0.9335
# Accuracy colors: 0.9442
#
# Epoch 20
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0328 - val_loss: 0.1181
# Flipped 3.3775 % of all elements
# Mean IOU: 0.387882367673
# Mean dist: 0.114495456776
# Mean mse: 0.00909718864336
# Accuracy shapes: 0.9470125
# Accuracy colors: 0.9543125
# --------------- TEST ----------------
# Flipped 4.18 % of all elements
# Mean IOU: 0.379642998994
# Mean dist: 0.115797125036
# Mean mse: 0.00920815288283
# Accuracy shapes: 0.9361
# Accuracy colors: 0.9442
#
# Epoch 21
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0321 - val_loss: 0.1215
# Flipped 3.5675 % of all elements
# Mean IOU: 0.394824501828
# Mean dist: 0.111992298236
# Mean mse: 0.00883628803056
# Accuracy shapes: 0.9489875
# Accuracy colors: 0.955375
# --------------- TEST ----------------
# Flipped 4.67 % of all elements
# Mean IOU: 0.386731644858
# Mean dist: 0.113769448498
# Mean mse: 0.00898164545277
# Accuracy shapes: 0.93555
# Accuracy colors: 0.94605
#
# Epoch 22
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0315 - val_loss: 0.1216
# Flipped 3.8125 % of all elements
# Mean IOU: 0.388582799628
# Mean dist: 0.112526834957
# Mean mse: 0.00885314047625
# Accuracy shapes: 0.948925
# Accuracy colors: 0.958075
# --------------- TEST ----------------
# Flipped 4.75 % of all elements
# Mean IOU: 0.379310729602
# Mean dist: 0.11402238307
# Mean mse: 0.00897834630201
# Accuracy shapes: 0.93835
# Accuracy colors: 0.9486
#
# Epoch 23
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0312 - val_loss: 0.1228
# Flipped 3.4525 % of all elements
# Mean IOU: 0.406700365319
# Mean dist: 0.107524207114
# Mean mse: 0.00847088028763
# Accuracy shapes: 0.951925
# Accuracy colors: 0.9590125
# --------------- TEST ----------------
# Flipped 4.07 % of all elements
# Mean IOU: 0.398076697652
# Mean dist: 0.109136528016
# Mean mse: 0.00861952649885
# Accuracy shapes: 0.94065
# Accuracy colors: 0.94705
#
# Epoch 24
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0307 - val_loss: 0.1216
# Flipped 3.39 % of all elements
# Mean IOU: 0.408052341651
# Mean dist: 0.105968724066
# Mean mse: 0.00832737513824
# Accuracy shapes: 0.9516125
# Accuracy colors: 0.9593125
# --------------- TEST ----------------
# Flipped 3.84 % of all elements
# Mean IOU: 0.398332260356
# Mean dist: 0.107945743777
# Mean mse: 0.0084925695858
# Accuracy shapes: 0.9403
# Accuracy colors: 0.9496
#
# Epoch 25
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0303 - val_loss: 0.1203
# Flipped 3.1975 % of all elements
# Mean IOU: 0.399444738811
# Mean dist: 0.108970942113
# Mean mse: 0.00845952584794
# Accuracy shapes: 0.9536125
# Accuracy colors: 0.9592375
# --------------- TEST ----------------
# Flipped 3.88 % of all elements
# Mean IOU: 0.390908656053
# Mean dist: 0.110873455775
# Mean mse: 0.00864086471079
# Accuracy shapes: 0.94155
# Accuracy colors: 0.94905
#
# Epoch 26
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0298 - val_loss: 0.1240
# Flipped 2.7975 % of all elements
# Mean IOU: 0.403870853115
# Mean dist: 0.106289449844
# Mean mse: 0.00825212204863
# Accuracy shapes: 0.9546125
# Accuracy colors: 0.961625
# --------------- TEST ----------------
# Flipped 3.6 % of all elements
# Mean IOU: 0.394834154953
# Mean dist: 0.108304742144
# Mean mse: 0.00843570931543
# Accuracy shapes: 0.93965
# Accuracy colors: 0.95195
#
# Epoch 27
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0293 - val_loss: 0.1241
# Flipped 2.925 % of all elements
# Mean IOU: 0.405735203005
# Mean dist: 0.106087968668
# Mean mse: 0.00819873883474
# Accuracy shapes: 0.9556875
# Accuracy colors: 0.9621
# --------------- TEST ----------------
# Flipped 3.57 % of all elements
# Mean IOU: 0.397145989334
# Mean dist: 0.107796057447
# Mean mse: 0.00837177632156
# Accuracy shapes: 0.942
# Accuracy colors: 0.95165
#
# Epoch 28
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0291 - val_loss: 0.1231
# Flipped 2.9775 % of all elements
# Mean IOU: 0.408312534846
# Mean dist: 0.10639512336
# Mean mse: 0.00820833197094
# Accuracy shapes: 0.956175
# Accuracy colors: 0.9631625
# --------------- TEST ----------------
# Flipped 3.81 % of all elements
# Mean IOU: 0.399529933468
# Mean dist: 0.108522732611
# Mean mse: 0.00841127135779
# Accuracy shapes: 0.94125
# Accuracy colors: 0.9528
#
# Epoch 29
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0285 - val_loss: 0.1227
# Flipped 3.0825 % of all elements
# Mean IOU: 0.406425872149
# Mean dist: 0.105700829991
# Mean mse: 0.00819483775349
# Accuracy shapes: 0.95485
# Accuracy colors: 0.9620625
# --------------- TEST ----------------
# Flipped 3.5 % of all elements
# Mean IOU: 0.397577713655
# Mean dist: 0.108007960644
# Mean mse: 0.00840404783616
# Accuracy shapes: 0.94185
# Accuracy colors: 0.95285
#
# Epoch 30
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0284 - val_loss: 0.1213
# Flipped 2.79 % of all elements
# Mean IOU: 0.413987180595
# Mean dist: 0.102676895453
# Mean mse: 0.00793057668882
# Accuracy shapes: 0.9586875
# Accuracy colors: 0.96505
# --------------- TEST ----------------
# Flipped 3.37 % of all elements
# Mean IOU: 0.404215634116
# Mean dist: 0.104995147986
# Mean mse: 0.00815489321227
# Accuracy shapes: 0.9451
# Accuracy colors: 0.9537
#
# Epoch 31
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0279 - val_loss: 0.1233
# Flipped 3.2475 % of all elements
# Mean IOU: 0.408749845289
# Mean dist: 0.104841085992
# Mean mse: 0.00806649367049
# Accuracy shapes: 0.95715
# Accuracy colors: 0.9644375
# --------------- TEST ----------------
# Flipped 4.17 % of all elements
# Mean IOU: 0.399753682015
# Mean dist: 0.107149384649
# Mean mse: 0.00826373518683
# Accuracy shapes: 0.943
# Accuracy colors: 0.9547
#
# Epoch 32
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0280 - val_loss: 0.1238
# Flipped 3.3225 % of all elements
# Mean IOU: 0.404562073848
# Mean dist: 0.105805087248
# Mean mse: 0.00811353517253
# Accuracy shapes: 0.954875
# Accuracy colors: 0.9644
# --------------- TEST ----------------
# Flipped 4.24 % of all elements
# Mean IOU: 0.394797758417
# Mean dist: 0.107687113248
# Mean mse: 0.00827537918696
# Accuracy shapes: 0.9391
# Accuracy colors: 0.9532
#
# Epoch 33
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0279 - val_loss: 0.1233
# Flipped 3.22 % of all elements
# Mean IOU: 0.41176343598
# Mean dist: 0.103226231586
# Mean mse: 0.00787667297861
# Accuracy shapes: 0.960325
# Accuracy colors: 0.9651375
# --------------- TEST ----------------
# Flipped 4.2 % of all elements
# Mean IOU: 0.401999632475
# Mean dist: 0.105547302108
# Mean mse: 0.00809349588974
# Accuracy shapes: 0.9457
# Accuracy colors: 0.95315
#
# Epoch 34
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0275 - val_loss: 0.1243
# Flipped 2.6875 % of all elements
# Mean IOU: 0.410856653009
# Mean dist: 0.103246568922
# Mean mse: 0.00789210718039
# Accuracy shapes: 0.96095
# Accuracy colors: 0.9658625
# --------------- TEST ----------------
# Flipped 3.61 % of all elements
# Mean IOU: 0.401424900452
# Mean dist: 0.105338528183
# Mean mse: 0.00807141625986
# Accuracy shapes: 0.9486
# Accuracy colors: 0.9539
#
# Epoch 35
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0271 - val_loss: 0.1228
# Flipped 2.9125 % of all elements
# Mean IOU: 0.419634930029
# Mean dist: 0.100608753535
# Mean mse: 0.0076645926181
# Accuracy shapes: 0.9612
# Accuracy colors: 0.966575
# --------------- TEST ----------------
# Flipped 3.71 % of all elements
# Mean IOU: 0.409750196896
# Mean dist: 0.103056477395
# Mean mse: 0.00788790202367
# Accuracy shapes: 0.9468
# Accuracy colors: 0.9594
#
# Epoch 36
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0267 - val_loss: 0.1265
# Flipped 2.825 % of all elements
# Mean IOU: 0.416527663345
# Mean dist: 0.102040820816
# Mean mse: 0.00775374923278
# Accuracy shapes: 0.9611625
# Accuracy colors: 0.9653625
# --------------- TEST ----------------
# Flipped 3.94 % of all elements
# Mean IOU: 0.406900968201
# Mean dist: 0.103965654436
# Mean mse: 0.0079425805831
# Accuracy shapes: 0.94705
# Accuracy colors: 0.95465
#
# Epoch 37
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0265 - val_loss: 0.1250
# Flipped 2.875 % of all elements
# Mean IOU: 0.420418120747
# Mean dist: 0.0998739940593
# Mean mse: 0.00754436502007
# Accuracy shapes: 0.9629375
# Accuracy colors: 0.96775
# --------------- TEST ----------------
# Flipped 3.63 % of all elements
# Mean IOU: 0.411035767597
# Mean dist: 0.102277392054
# Mean mse: 0.00776329559205
# Accuracy shapes: 0.9476
# Accuracy colors: 0.958
#
# Epoch 38
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0263 - val_loss: 0.1265
# Flipped 2.8125 % of all elements
# Mean IOU: 0.415505721738
# Mean dist: 0.100898095252
# Mean mse: 0.00764424185577
# Accuracy shapes: 0.962
# Accuracy colors: 0.9677875
# --------------- TEST ----------------
# Flipped 3.36 % of all elements
# Mean IOU: 0.404941724999
# Mean dist: 0.103679823952
# Mean mse: 0.00786993413468
# Accuracy shapes: 0.9473
# Accuracy colors: 0.95655
#
# Epoch 39
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0261 - val_loss: 0.1257
# Flipped 2.69 % of all elements
# Mean IOU: 0.424564615499
# Mean dist: 0.0981725937415
# Mean mse: 0.00744081551778
# Accuracy shapes: 0.9642375
# Accuracy colors: 0.969925
# --------------- TEST ----------------
# Flipped 3.43 % of all elements
# Mean IOU: 0.414703773623
# Mean dist: 0.10096824487
# Mean mse: 0.00769844686877
# Accuracy shapes: 0.95005
# Accuracy colors: 0.9611
#
# Epoch 40
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0256 - val_loss: 0.1245
# Flipped 2.715 % of all elements
# Mean IOU: 0.416816940816
# Mean dist: 0.100795994962
# Mean mse: 0.00754879556114
# Accuracy shapes: 0.96505
# Accuracy colors: 0.9698375
# --------------- TEST ----------------
# Flipped 3.45 % of all elements
# Mean IOU: 0.406533501366
# Mean dist: 0.103350369615
# Mean mse: 0.00777985369066
# Accuracy shapes: 0.94995
# Accuracy colors: 0.9588
#
# Epoch 41
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0256 - val_loss: 0.1259
# Flipped 2.4375 % of all elements
# Mean IOU: 0.422697743081
# Mean dist: 0.0978656004839
# Mean mse: 0.00737206074562
# Accuracy shapes: 0.9668375
# Accuracy colors: 0.9706875
# --------------- TEST ----------------
# Flipped 3.29 % of all elements
# Mean IOU: 0.412824423675
# Mean dist: 0.100417530694
# Mean mse: 0.00760730055759
# Accuracy shapes: 0.95185
# Accuracy colors: 0.95975
#
# Epoch 42
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0252 - val_loss: 0.1257
# Flipped 2.3625 % of all elements
# Mean IOU: 0.422737025396
# Mean dist: 0.099141734367
# Mean mse: 0.0073701733643
# Accuracy shapes: 0.966375
# Accuracy colors: 0.9722125
# --------------- TEST ----------------
# Flipped 3.22 % of all elements
# Mean IOU: 0.412733299955
# Mean dist: 0.101737968558
# Mean mse: 0.00760280892309
# Accuracy shapes: 0.95125
# Accuracy colors: 0.96055
#
# Epoch 43
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0250 - val_loss: 0.1250
# Flipped 2.2025 % of all elements
# Mean IOU: 0.4252943166
# Mean dist: 0.0974690680787
# Mean mse: 0.00731648171445
# Accuracy shapes: 0.9673125
# Accuracy colors: 0.9718375
# --------------- TEST ----------------
# Flipped 3.08 % of all elements
# Mean IOU: 0.415227327158
# Mean dist: 0.100214300938
# Mean mse: 0.00757143193384
# Accuracy shapes: 0.95185
# Accuracy colors: 0.95995
#
# Epoch 44
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0247 - val_loss: 0.1247
# Flipped 2.34 % of all elements
# Mean IOU: 0.420353591867
# Mean dist: 0.0983021475068
# Mean mse: 0.00734623551059
# Accuracy shapes: 0.96725
# Accuracy colors: 0.9716375
# --------------- TEST ----------------
# Flipped 3.39 % of all elements
# Mean IOU: 0.409607089638
# Mean dist: 0.10132211842
# Mean mse: 0.00760024847677
# Accuracy shapes: 0.95135
# Accuracy colors: 0.95935
#
# Epoch 45
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0246 - val_loss: 0.1259
# Flipped 2.2925 % of all elements
# Mean IOU: 0.421604965372
# Mean dist: 0.0983385527068
# Mean mse: 0.00727052226842
# Accuracy shapes: 0.9667
# Accuracy colors: 0.9718625
# --------------- TEST ----------------
# Flipped 3.01 % of all elements
# Mean IOU: 0.411070076941
# Mean dist: 0.101445276816
# Mean mse: 0.00754435281682
# Accuracy shapes: 0.95165
# Accuracy colors: 0.9595
#
# Epoch 46
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0245 - val_loss: 0.1249
# Flipped 2.185 % of all elements
# Mean IOU: 0.423282165821
# Mean dist: 0.0981862960357
# Mean mse: 0.00729736474147
# Accuracy shapes: 0.968775
# Accuracy colors: 0.973225
# --------------- TEST ----------------
# Flipped 2.99 % of all elements
# Mean IOU: 0.412787918072
# Mean dist: 0.101639174462
# Mean mse: 0.00759521900113
# Accuracy shapes: 0.9503
# Accuracy colors: 0.9603
#
# Epoch 47
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0241 - val_loss: 0.1240
# Flipped 2.2125 % of all elements
# Mean IOU: 0.42385351604
# Mean dist: 0.0985899254351
# Mean mse: 0.00731583695927
# Accuracy shapes: 0.9679375
# Accuracy colors: 0.973025
# --------------- TEST ----------------
# Flipped 3.01 % of all elements
# Mean IOU: 0.413378821272
# Mean dist: 0.101914699819
# Mean mse: 0.00761308063193
# Accuracy shapes: 0.9504
# Accuracy colors: 0.95905
#
# Epoch 48
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 48s - loss: 0.0240 - val_loss: 0.1275
# Flipped 2.0875 % of all elements
# Mean IOU: 0.431438927168
# Mean dist: 0.0946749228976
# Mean mse: 0.00702593173618
# Accuracy shapes: 0.9698875
# Accuracy colors: 0.9731875
# --------------- TEST ----------------
# Flipped 3.04 % of all elements
# Mean IOU: 0.42033194224
# Mean dist: 0.0979559929002
# Mean mse: 0.00732273750272
# Accuracy shapes: 0.95295
# Accuracy colors: 0.95965
#
# Epoch 49
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/1
# 10713s - loss: 0.0237 - val_loss: 0.1272
# Flipped 2.0675 % of all elements
# Mean IOU: 0.427254585185
# Mean dist: 0.0958538932462
# Mean mse: 0.00711176623209
# Accuracy shapes: 0.9691625
# Accuracy colors: 0.9735875
# --------------- TEST ----------------
# Flipped 2.84 % of all elements
# Mean IOU: 0.41625295394
# Mean dist: 0.0993014937617
# Mean mse: 0.00741618199698
# Accuracy shapes: 0.95145
# Accuracy colors: 0.9619

# %%
# model.layers
weights = model.layers[0].get_weights()[0]
weights = weights.transpose(3, 0, 1, 2)
print weights.shape
# plt.imshow(weights[0] * 255. + 128., interpolation='none', origin='lower')
print np.mean(weights[0]), np.std(weights[0]), np.min(weights[0]), np.max(weights[0])
adj_weights = (weights * 255.) + 128.
print np.mean(adj_weights[0]), np.std(adj_weights[0]), np.min(adj_weights[0]), np.max(adj_weights[0])
plt.figure(figsize=(16, 8))
for i in range(24):
    plt.subplot(4, 6, i+1)
    plt.imshow(adj_weights[i, :, :], interpolation='none', origin='lower', cmap='Greys')
# Out:
# (32L, 3L, 3L, 3L)
# -0.0109495 0.117415 -0.188681 0.263553
# 125.208 29.9409 79.8864 195.206

# %%
plt.pcolor(flipped[:1000], cmap='Greys', vmax=1.)
# plt.axvline(num_epochs_flipping, c='r')
plt.xlabel('Epoch')
plt.ylabel('Training sample')

# %%
mean_ious_epoch = np.mean(ious_epoch, axis=0)
mean_dists_epoch = np.mean(dists_epoch, axis=0)
mean_mses_epoch = np.mean(mses_epoch, axis=0)
plt.plot(mean_ious_epoch, label='Mean IOU')  # between predicted and assigned true bboxes
plt.plot(mean_dists_epoch, label='Mean distance')  # relative to image size
plt.plot(mean_mses_epoch, label='Mean mse')  # relative to image size
plt.annotate(np.round(np.max(mean_ious_epoch), 3), (len(mean_ious_epoch)-1, mean_ious_epoch[-1]+0.03), horizontalalignment='right', color='b')
plt.annotate(np.round(np.min(mean_dists_epoch), 3), (len(mean_dists_epoch)-1, mean_dists_epoch[-1]+0.03), horizontalalignment='right', color='g')
plt.annotate(np.round(np.min(mean_mses_epoch), 3), (len(mean_mses_epoch)-1, mean_mses_epoch[-1]+0.03), horizontalalignment='right', color='r')

# TEST.
mean_ious_epoch = np.mean(ious_test_epoch, axis=0)
mean_dists_epoch = np.mean(dists_test_epoch, axis=0)
mean_mses_epoch = np.mean(mses_test_epoch, axis=0)
plt.plot(mean_ious_epoch, 'b--')  # between predicted and assigned true bboxes
plt.plot(mean_dists_epoch, 'g--')  # relative to image size
plt.plot(mean_mses_epoch, 'r--')  # relative to image size
# plt.annotate(np.round(np.max(mean_ious_epoch), 3), (len(mean_ious_epoch)-1, mean_ious_epoch[-1]+0.03), horizontalalignment='right', color='b')
# plt.annotate(np.round(np.min(mean_dists_epoch), 3), (len(mean_dists_epoch)-1, mean_dists_epoch[-1]+0.03), horizontalalignment='right', color='g')
# plt.annotate(np.round(np.min(mean_mses_epoch), 3), (len(mean_mses_epoch)-1, mean_mses_epoch[-1]+0.03), horizontalalignment='right', color='r')

# plt.axvline(num_epochs_flipping, c='r')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.ylim(0, 0.6)

# plt.savefig('plots/color-multiple-shapes_three-colors_bboxes.png', dpi=300)
# Out:
# (0, 0.6)

# %%
mean_acc_shapes_epoch = np.mean(acc_shapes_epoch, axis=0)
mean_acc_colors_epoch = np.mean(acc_colors_epoch, axis=0)
plt.plot(mean_acc_shapes_epoch, label='Accuracy shapes')  # between predicted and assigned true bboxes
plt.plot(mean_acc_colors_epoch, label='Accuracy colors')
plt.annotate(np.round(np.max(mean_acc_shapes_epoch), 3), (len(mean_acc_shapes_epoch)-1, mean_acc_shapes_epoch[-1]+0.03), horizontalalignment='right', color='b')
plt.annotate(np.round(np.max(mean_acc_colors_epoch), 3), (len(mean_acc_colors_epoch)-1, mean_acc_colors_epoch[-1]+0.03), horizontalalignment='right', color='g')

# TEST.
mean_acc_shapes_epoch = np.mean(acc_shapes_test_epoch, axis=0)
mean_acc_colors_epoch = np.mean(acc_colors_test_epoch, axis=0)
plt.plot(mean_acc_shapes_epoch, 'b--')  # between predicted and assigned true bboxes
plt.plot(mean_acc_colors_epoch, 'g--')
# plt.annotate(np.round(np.max(mean_acc_shapes_epoch), 3), (len(mean_acc_shapes_epoch)-1, mean_acc_shapes_epoch[-1]+0.03), horizontalalignment='right', color='b')
# plt.annotate(np.round(np.max(mean_acc_colors_epoch), 3), (len(mean_acc_colors_epoch)-1, mean_acc_colors_epoch[-1]+0.03), horizontalalignment='right', color='g')

# plt.axvline(num_epochs_flipping, c='r')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.ylim(0.5, 1)

# plt.savefig('plots/color-multiple-shapes_three-colors_classification.png', dpi=300)
# Out:
# (0.5, 1)

# %%
pred_y = model.predict(test_X)
pred_y = pred_y.reshape(len(pred_y), num_objects, -1)
pred_bboxes = pred_y[..., :4] * img_size
pred_shapes = np.argmax(pred_y[..., 4:4+num_shapes], axis=-1).astype(int)  # take max from probabilities
# print pred_y[..., 4+num_shapes:4+num_shapes+num_colors].shape
# print np.argmax(pred_y[..., 5:8], axis=-1).shape
pred_colors = np.argmax(pred_y[..., 4+num_shapes:4+num_shapes+num_colors], axis=-1).astype(int)
pred_bboxes.shape, pred_shapes.shape, pred_colors.shape
# Out:
# ((10000L, 3L, 4L), (10000L, 3L), (10000L, 3L))

# %%
plt.figure(figsize=(16, 8))
for i_subplot in range(1, 9):
    plt.subplot(2, 4, i_subplot)
    i = np.random.randint(len(test_X))
    plt.imshow(test_imgs[i], interpolation='none', origin='lower', extent=[0, img_size, 0, img_size])
    for bbox, shape, color in zip(pred_bboxes[i], pred_shapes[i], pred_colors[i]):
        plt.gca().add_patch(matplotlib.patches.Rectangle((bbox[0], bbox[1]), bbox[2], bbox[3], ec='k', fc='none'))
        plt.annotate(shape_labels[shape], (bbox[0], bbox[1] + bbox[3] + 0.7), color=color_labels[color], clip_on=False, bbox={'fc': 'w', 'ec': 'none', 'pad': 1, 'alpha': 0.6})

# %%
np.mean(pred_bboxes[:, :, 2]), np.std(pred_bboxes[:, :, 2])
# Out:
# (9.4930956365744272, 1.1636418081717976)
